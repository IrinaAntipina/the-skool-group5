# %% [markdown]
# # Inledning
#
# # Analysens syfte och omfattning
#
# Vi analyserar utvecklingen av statliga medel till olika utbildningsområden från 2012 till 2024 för att förstå trender och prioriteringar inom svensk utbildningspolitik.
#
# Viktigaste frågorna vi undersöker:
# * Hur har fördelningen av medel utvecklats över tid?
# * Vilka utbildningsområden har vuxit mest?
# * Vad säger trenderna om framtida kompetensbehov?
#
# Varför är detta viktigt för stakeholders:
# * Utbildningsministrar: Resursallokering och prioritering
# * Skolledare: Strategisk planering och satsningar
# * Studenter: Förståelse för vilka områden som prioriteras
# * Arbetsgivare: Insikt i kompetensutbud och framtida trender

# %%
import pandas as pd 

df = pd.read_excel("data/ek_1_utbet_statliga_medel_utbomr.xlsx", sheet_name="Utbetalda statliga medel", skiprows=5, skipfooter=4)
df
# Out:
#                                Utbildningsområde         2012         2013  \
# 0                                        Data/IT   109.192749   136.592343
# 1        Ekonomi, administration och försäljning   333.379221   373.196476
# 2                       Friskvård och kroppsvård    12.385036    12.129508
# 3                  Hotell, restaurang och turism    76.257076    78.752007
# 4        Hälso- och sjukvård samt socialt arbete   118.890913   130.518945
# 5                   Journalistik och information     8.323028    11.691712
# 6                                        Juridik     6.285412     9.027900
# 7                       Kultur, media och design    87.487106    96.421940
# 8   Lantbruk, djurvård, trädgård, skog och fiske    51.798081    55.014831
# 9                     Pedagogik och undervisning    17.567920    17.970322
# 10                Samhällsbyggnad och byggteknik   144.764251   180.390592
# ...

# %%
import pandas as pd

df = pd.read_excel(
    "data/ek_1_utbet_statliga_medel_utbomr.xlsx",
    sheet_name="Utbetalda statliga medel",
    skiprows=5,
    skipfooter=4
)

display(df.head())
# Out:
#                          Utbildningsområde        2012        2013  \
# 0                                  Data/IT  109.192749  136.592343
# 1  Ekonomi, administration och försäljning  333.379221  373.196476
# 2                 Friskvård och kroppsvård   12.385036   12.129508
# 3            Hotell, restaurang och turism   76.257076   78.752007
# 4  Hälso- och sjukvård samt socialt arbete  118.890913  130.518945
#
#          2014        2015        2016        2017        2018        2019  \
# 0  154.726348  192.765796  211.257113  198.036024  203.249950  246.098128
# 1  392.273449  397.432949  381.773874  406.235745  469.265158  549.522420
# 2   12.160803   11.943787   10.835978    7.151950   10.021599   12.640847
# 3   81.725028   81.591173   78.335025   79.393923   83.923865   89.100543
# 4  148.016792  174.665651  177.475662  194.507055  219.279194  257.937313
#
#          2020        2021        2022        2023        2024
# ...

# %% [markdown]
# * Visualisering 1: Utveckling av topp 3 utbildningsområden
#
# Denna visualisering visar hur de tre största utbildningsområdena
# * Data/IT, Ekonomi/Administration och Teknik/Tillverkning har utvecklats från 2012 till 2024.
# * Data/IT har ökat från 120 till 665 miljoner kronor, en ökning på hela 454%
# * Ekonomi/Administration har vuxit stadigt från 320 till 664 miljoner kronor
# * Teknik och tillverkning växer också men i långsammare takt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df_correct = pd.read_excel(
    "data/ek_1_utbet_statliga_medel_utbomr.xlsx",
    sheet_name='Utbetalda statliga medel',
    header=5
)
df_correct = df_correct.set_index('Utbildningsområde')

df_correct = df_correct.drop(columns=['Totalt'], errors='ignore')

top4 = df_correct[2024].sort_values(ascending=False).head(4).index.tolist()

years = df_correct.columns.astype(str).tolist()
bar_width = 0.2
x = np.arange(len(years))

colors = ['#4B4B4B', '#02D9FF', "#278D5A", '#D3D3D3']

plt.figure(figsize=(12,7))

for i, area in enumerate(top4):
    values = df_correct.loc[area].values
    plt.bar(x + i*bar_width, values, width=bar_width, label=area, color=colors[i])

plt.xticks(x + bar_width, years, rotation=45)
plt.xlabel('År')
plt.ylabel('Utbetalda statliga medel (miljoner kronor)')
plt.title('Utveckling av statliga medel 2012-2024 för topp 3 utbildningsområden')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# * Visualisering 2: Procentuell fördelning över tid
#
# Denna graf visar hur de olika utbildningsområdenas relativa andelar har förändrats från 2012 till 2024.
# * Data/IT har ökat från 4.7% till 9.4% nästan en fördubbling
# * Ekonomi/Administration minskar relativt sett från 13% till 9.4%
# * Samhällsbyggnad växer stadigt från 5.7% till 7.5%
#
# Rekommendationer
# * Data/IT-trenden förväntas fortsätta växa
# * Samhällsbyggnad visar stabild tillväxt viktig för infrastruktur

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df.columns = df.columns.astype(str)

years = [str(year) for year in range(2012, 2025)]
df_areas = df.set_index('Utbildningsområde')[years].dropna()

df_percent = df_areas.div(df_areas.sum(axis=0), axis=1) * 100
df_percent = df_percent.drop("Totalt", errors='ignore')

top_n = 6
df_percent['mean'] = df_percent.mean(axis=1)
df_percent_sorted = df_percent.sort_values('mean', ascending=False)
top_categories = df_percent_sorted.head(top_n).drop(columns='mean')
other_categories = df_percent_sorted.iloc[top_n:].drop(columns='mean').sum().to_frame().T
other_categories.index = ["Övriga områden"]
df_final = pd.concat([top_categories, other_categories])

fig, ax = plt.subplots(figsize=(16, 10))

box = ax.get_position()
ax.set_position([box.x0 + 0.35, box.y0, box.width - 0.35, box.height])

width = 0.10
x = np.arange(len(years))

colors = ['#02D9FF', '#333333', '#4d4d4d', "#02FF74", '#808080', '#999999', '#b3b3b3']

for i, area in enumerate(df_final.index):
    ax.bar(x + i * width, df_final.loc[area], width, label=area, color=colors[i], edgecolor='black')

ax.set_title('Procentuell fördelning av statliga medel över utbildningsområden (2012–2024)', 
             fontsize=18, fontweight='bold')
ax.set_xlabel('År', fontsize=14)
ax.set_ylabel('Procentuell fördelning (%)', fontsize=14)
ax.set_xticks(x + width * (len(df_final.index)-1)/2)
ax.set_xticklabels(years, rotation=45)

leg = ax.legend(title='Utbildningsområde', bbox_to_anchor=(1.02, 1), loc='upper left', fontsize=11, title_fontsize=12)

for patch in leg.get_patches():
    patch.set_width(14)
    patch.set_height(14)

for text in leg.get_texts():
    text.set_fontsize(11)

ax.grid(axis='y', linestyle='--', alpha=0.6)

left = 1.02
bottom = 0.15
width = 0.32
height = 0.55

ax_table = fig.add_axes([left, bottom, width, height])
ax_table.axis('off')

cell_text = []
for area in df_final.index:
    row = [f"{df_final.loc[area, year]:.1f}%" for year in years]
    cell_text.append(row)

table = ax_table.table(cellText=cell_text,
                       rowLabels=df_final.index,
                       colLabels=years,
                       loc='center',
                       cellLoc='center',
                       rowLoc='center',
                       edges='closed')

table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 2)

for key, cell in table.get_celld().items():
    cell.get_text().set_fontfamily('monospace')
    cell.get_text().set_color('black')
    if key[0] == 0 or key[1] == -1:
        cell.set_text_props(weight='bold')
        cell.set_facecolor('#bfbfbf')
    else:
        cell.set_facecolor('#ffffff')

plt.subplots_adjust(left=0.005, right=0.73, top=0.97, bottom=0.1)
plt.show()

# %% [markdown]
# * Visualisering 3: Totala utbetalningar per område 2024
#
# Analys av nuvarande fördelning
# Denna horisontella stapelgraf visar den totala fördelningen av statliga medel per utbildningsområde för 2024.
#
# * Data/IT toppar med 665 miljoner kronor - endast 1 miljon mer än Ekonomi/Administration
# * Topp 4 områden Data/IT, Ekonomi, Teknik, Samhällsbyggnad får 70% av alla medel
# * Stor skillnad mellan topp områden och specialiserade områden som Juridik, som endast får 12 miljoner

# %%
import matplotlib.pyplot as plt
import numpy as np

year = 2024

categories = [
    "Totalt",
    "Data/IT",
    "Ekonomi, administration och försäljning",
    "Teknik och tillverkning",
    "Samhällsbyggnad och byggteknik",
    "Hälso- och sjukvård samt socialt arbete",
    "Kultur, media och design",
    "Lantbruk, djurvård, trädgård, skog och fiske",
    "Hotell, restaurang och turism",
    "Transporttjänster",
    "Pedagogik och undervisning",
    "Övrigt",
    "Säkerhetstjänster",
    "Journalistik och information",
    "Friskvård och kroppsvård",
    "Juridik"
]

values = [3530, 665, 664, 619, 530, 340, 231, 127, 100, 96, 46, 29, 29, 23, 17, 12]

categories = categories[1:]
values = values[1:]

sorted_indices = np.argsort(values)[::-1]
sorted_categories = [categories[i] for i in sorted_indices]
sorted_values = [values[i] for i in sorted_indices]

max_white = 700
max_value = max(sorted_values)
scaled_values = [v / max_value * max_white for v in sorted_values]

colors = ['#02D9FF' if i < 2 else '#a3a3a3' for i in range(len(scaled_values))]

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 8))

for spine in ax.spines.values():
    spine.set_visible(False)

bars = ax.barh(sorted_categories, scaled_values, color=colors)
ax.invert_yaxis()

ax.set_title(f"Utbetalda statliga medel per utbildningsområde år {year}",
             fontsize=16, fontweight='bold', color='white', pad=20)
ax.set_xlabel("Miljoner kronor", fontsize=12, color='white')
ax.set_ylabel("")
ax.grid(axis="x", linestyle="--", alpha=0)

ax.set_xlim(0, max_white + 150)

for i, bar in enumerate(bars):
    width = bar.get_width()
    yloc = bar.get_y() + bar.get_height() / 2
    orig_value = sorted_values[i]
    ax.text(width + 15, yloc, f'{int(orig_value)}', va='center', ha='left', color='white', fontsize=12)

ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

index_pil = 1
bar_pil = bars[index_pil]
x_start = 720
y_start = 0.5


ax.annotate(
    "Endast 1 miljon skillnad i statsbidrag",
    xy=(x_start, y_start),
    xytext=(x_start + 80, y_start + 1),
    arrowprops=dict(
        arrowstyle='-|>',
        connectionstyle='arc3,rad=0.1',
        color='white',
        lw=1.5
    ),
    fontsize=12,
    color='white',
    ha='left',
    va='center'
)


plt.subplots_adjust(left=0.1, right=1.0, top=1.0, bottom=0.1)

plt.show()
