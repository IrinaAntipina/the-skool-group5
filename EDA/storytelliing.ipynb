# %% [markdown]
# Struktur för Storytelling Notebook:
# Inledning och kontext
#
# Vilka data analyserar vi (YH-kurser 2024)
#
# Vilka frågor vill vi undersökavälj
#
# Varför är detta viktigt för intressenter (stakeholders)
#
# 2–3 nyckelvisualiseringar (måste göras med matplotlib)
#
# Välj de viktigaste och mest illustrativa graferna
#
# Exempel:
#
# Geografisk fördelning av kurser (karta eller topplistor per region)
#
# Skolors framgångsnivå i att få ansökningar godkända
#
# Populäritet för olika utbildningsinriktningar
#
# Berättelse till varje visualisering:
#
# Vad visar grafen
#
# Vilka insikter kan vi dra
#
# Vilka slutsatser och rekommendationer kan vi ge
#
# Sammanfattande slutsatser och rekommendationer
#
# Sammanfatta viktiga fynd
#
# Ge praktiska rekommendationer till stakeholders
#
# Rekommenderad struktur:
# Titel
# YH-kurser 2024: Analys av ansökningsresultat
# En studie för strategiskt beslutsfattande
#
# Inledning
# Förklara varför analysen av data om YH-kurser är viktig
#
# Visualisering 1: Geografisk fördelning
#
# Analys: Var koncentreras kurserna? Vilka regioner är underrepresenterade?
#
# Visualisering 2: Skolors framgångsnivå
#
#
# Analys: Vilka skolor är mest framgångsrika? Mönster och trender?
#
# Visualisering 3: Populäritet för utbildningsområden
#
# Analys: Vilka inriktningar är mest efterfrågade? Trender?
#
# Slutsatser och rekommendationer
# Sammanfattande insikter för stakeholders
#
# Viktiga punkter:
# Använd endast matplotlib för visualiseringar
#
# Fokusera på storytelling – berätta en historia, inte bara visa grafer
#
# Tänk på din publik (stakeholders) – vad är viktigt för dem att veta?
#
# Använd tydliga rubriker och förklaringar
#
# Lägg till markdown-celler med textförklaringar mellan kodblocken
#
# Detta ska vara en separat notebook från dina EDA-notebooks – speciellt utformad för att presentera resultaten.
